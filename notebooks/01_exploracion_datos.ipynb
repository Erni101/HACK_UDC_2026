# %% [markdown]
# # 01 — Exploración inicial de datos
#
# **Objetivo:** cargar el dataset, revisar su estructura y detectar problemas de calidad.
#
# **Autor:** *(nombre)*
# **Fecha:** *(fecha)*

# %%
# Instalar dependencias si es necesario
# %pip install -r ../requirements.txt

# %%
import sys
sys.path.insert(0, '..')  # permite importar desde src/

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import settings
from src.data.loader import load_dataset

sns.set_theme(style='whitegrid')
print('Dependencias cargadas ✅')

# %% [markdown]
# ## 1. Carga de datos

# %%
# Ajusta la ruta si es necesario
DATA_PATH = settings.data_path

# df = load_dataset(DATA_PATH)
# df.head()

# %% [markdown]
# ## 2. Estructura del dataset

# %%
# df.shape
# df.dtypes
# df.info()

# %% [markdown]
# ## 3. Estadísticas descriptivas

# %%
# df.describe()

# %% [markdown]
# ## 4. Valores nulos

# %%
# null_counts = df.isnull().sum()
# null_counts[null_counts > 0]

# %% [markdown]
# ## 5. Visualizaciones rápidas

# %%
# fig, ax = plt.subplots(figsize=(10, 4))
# df.select_dtypes('number').hist(ax=ax)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 6. Conclusiones y próximos pasos
#
# - *(Escribe aquí tus observaciones)*
# - *(Próximos pasos: limpieza, feature engineering, modelo baseline…)*
